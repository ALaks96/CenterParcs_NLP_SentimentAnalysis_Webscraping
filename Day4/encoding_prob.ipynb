# %%
import string
import pandas as pd

# %%
# NLP library imports
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/laks/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/laks/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/laks/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_json('don4_us.json')
df.head()
# Out:
#                                         hotel_adress  \
# 0  {'@type': 'PostalAddress', 'streetAddress': 'R...
# 1  {'@type': 'PostalAddress', 'streetAddress': 'R...
# 2  {'@type': 'PostalAddress', 'streetAddress': 'R...
# 3  {'@type': 'PostalAddress', 'streetAddress': 'R...
# 4  {'@type': 'PostalAddress', 'streetAddress': 'R...
#
#                        hotel_name       hotel_type  \
# 0  Center Parcs Le Bois aux Daims  LodgingBusiness
# 1  Center Parcs Le Bois aux Daims  LodgingBusiness
# 2  Center Parcs Le Bois aux Daims  LodgingBusiness
# 3  Center Parcs Le Bois aux Daims  LodgingBusiness
# 4  Center Parcs Le Bois aux Daims  LodgingBusiness
#
#                                            image_url    locid    pid  \
# 0  https://media-cdn.tripadvisor.com/media/photo-...  7107948  38673
# 1  https://media-cdn.tripadvisor.com/media/photo-...  7107948  38673
# 2  https://media-cdn.tripadvisor.com/media/photo-...  7107948  38673
# 3  https://media-cdn.tripadvisor.com/media/photo-...  7107948  38673
# 4  https://media-cdn.tripadvisor.com/media/photo-...  7107948  38673
#
#                                          price_range      published_date  \
# 0  $ (Based on Average Nightly Rates for a Standa...  September 26, 2018
# 1  $ (Based on Average Nightly Rates for a Standa...     October 1, 2018
# 2  $ (Based on Average Nightly Rates for a Standa...     October 4, 2018
# 3  $ (Based on Average Nightly Rates for a Standa...     October 4, 2018
# 4  $ (Based on Average Nightly Rates for a Standa...   December 23, 2018
#
#    rating                                             review  review_id  \
# 0       3  Plenty to do for amusement. Paying activities ...  619749851
# 1       3  Nice place to relax, The park is quiet and gre...  621087330
# 2       4  we had a lovely long weekend and it was tough ...  622158065
# 3       5  Thoroughly enjoyable time at Bois aux daims, e...  622168041
# 4       4  Can\u2019t complain except for the fact that t...  641185888
#
#   review_language                       reviewer_id  \
# 0              en  59F1468A0F56AE011EED15990BE2B7D6
# 1              en  4294D5DA68B56E9AFD34FC058E6F53B3
# 2              en  DBBE91383F1387D6AFF8ABD6F5FDA904
# 3              en  B2F94CE6E2F20A01493BC76C46F7CDB9
# 4              en  44482273FACD61FCD70CC8793A1345DC
#
#                                          title        trip_date  \
# 0                                Super weekend   September 2018
# 1  Relaxing stay with depressing food offering   September 2018
# 2                                 long weekend   September 2018
# 3                                         Yay!   September 2018
# 4                             Almost perfect!     December 2018
#
#               trip_type
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4  Traveled with family

# %%
df1 = df.copy()
df1 = df1.drop(["hotel_adress","hotel_type","image_url","locid","pid","price_range","review_id","reviewer_id","trip_type"], axis = 1)
df1.head()
# Out:
#                        hotel_name      published_date  rating  \
# 0  Center Parcs Le Bois aux Daims  September 26, 2018       3
# 1  Center Parcs Le Bois aux Daims     October 1, 2018       3
# 2  Center Parcs Le Bois aux Daims     October 4, 2018       4
# 3  Center Parcs Le Bois aux Daims     October 4, 2018       5
# 4  Center Parcs Le Bois aux Daims   December 23, 2018       4
#
#                                               review review_language  \
# 0  Plenty to do for amusement. Paying activities ...              en
# 1  Nice place to relax, The park is quiet and gre...              en
# 2  we had a lovely long weekend and it was tough ...              en
# 3  Thoroughly enjoyable time at Bois aux daims, e...              en
# 4  Can\u2019t complain except for the fact that t...              en
#
#                                          title        trip_date
# 0                                Super weekend   September 2018
# 1  Relaxing stay with depressing food offering   September 2018
# 2                                 long weekend   September 2018
# 3                                         Yay!   September 2018
# 4                             Almost perfect!     December 2018

# %%
df1.review = df1.review.apply(lambda x:x.replace(r"\u00e8","è"))
df1.review = df1.review.apply(lambda x:x.replace(r'\u00e9', 'é'))
df1.review = df1.review.apply(lambda x:x.replace(r"\u00ea","ê"))
df1.review = df1.review.apply(lambda x:x.replace(r"\u00eb","ë"))
df1.review = df1.review.apply(lambda x:x.replace(r"\u00fb","û"))
df1.review = df1.review.apply(lambda x:x.replace(r"\u00f9","ù"))
df1.review = df1.review.apply(lambda x:x.replace(r'\u00e0', 'à'))
df1.review = df1.review.apply(lambda x:x.replace(r'\u00e2', 'â'))
df1.review = df1.review.apply(lambda x:x.replace(r'\u00f4', 'ô'))
df1.review = df1.review.apply(lambda x:x.replace(r'\u00ee', 'î'))
df1.review = df1.review.apply(lambda x:x.replace(r'\u00ef', 'ï'))
df1.review = df1.review.apply(lambda x:x.replace(r'\u2019', "'"))
df1.review = df1.review.apply(lambda x:x.replace(r'\'', "'"))

df1.review
# Out:
# 0       Premier séjour à center parc pour nous et nous...
# 1       sejour très agreable comme d habitude a center...
# 2       Cottage très bien, propre et chaud dès l'arriv...
# 3       Séjour très reposant à noter tout de même troi...
# 4       Arrivés pour trois nuits et deux jours en sema...
# 5       Center parc est un endroit très relaxant et en...
# 6       agréablement surpris super séjour bien reposer...
# 7       Piscine bondée de monde !! Et pourtant hors pé...
# 8       Le personnel du service client n'a pas été à l...
# 9       Un vrai paradis pour déconnecter du travail, d...
# 10      10 jours de détente en famille, que ce soit au...
# 11      très beau cadre en harmonie avec la naturedéco...
# 12      Séjour très agréable, très bon accueil, cottag...
# 13      le parc est calme , la nature est partout  et ...
# 14      Très bonnes installations. Seul bémol quota de...
# 15      Nous sommes venus en famille avec une amie et ...
# 16      Nous avons passé un très bon séjour! L 'enviro...
# 17      Le cottage VIP 6 personnes était juste super!!...
# 18      Toujours aussi bien j'y vais toujours avec pla...
# 19      Premier séjour à Center Parcs en famille avec ...
# 20      Cottage très bien agencé pour une famille nomb...
# 21      Bel endroit, très calme au niveau des cottages...
# 22      Bon séjour passé en famille le côté nature éta...
# 23      Nous avons passé une super semaine en famille....
# 24      Très dépaysant , surtout en hiver.Très adapté ...
# 25      émerveillement pour les enfants: l'endroit ide...
# 26      Un séjour magique en famille. Nous y sommes al...
# 27      c'est bon de pouvoir se baigner dans une eau&q...
# 28      Un geste commercial serait apprécié compte ten...
# 29      Je recommande center parc à toutes les personn...
#                               ...
# 1964    Cottage très agréable,  parcs très calme et sé...
# 1965    Le concept est reposant, les daims vous renden...
# 1966    Bonnes infrastructures neuves et de qualité ma...
# 1967    Notre troisième séjour à Center parcs est iden...
# 1968    C est la troisième fois que nous venons passer...
# 1969    Passer une journée dans le Center Parcs avis m...
# 1970    Nous sommes partis une semaine en cottage prem...
# 1971    Domaine magnifique dommage que le services dan...
# 1972    Ce séjour à Center Parcs était une grande prem...
# 1973    4 jours passés, très agréable le cottage très ...
# 1974    Nous avons voulu tester ce parc car moins loin...
# 1975    Mes 2 miss de 10 ans ont été éblouies et se so...
# 1976    Le parc, la piscine et le cottage sont très ag...
# 1977    emplacement ok,ménage: moutons de poussière so...
# 1978    Nous avons passés un agréable séjour à Center ...
# 1979    Mon enfant est tombé sur le nez en montant les...
# 1980    Le parc est magnifique, les daims sont bien pr...
# 1981    We très sympa a Center Parcs ressour\u00e7ant ...
# 1982    VACANCES sympa la cadre et les daims beaux spe...
# 1983    Tres dé\u00e7u par le bois aux daimsC'est le 2...
# 1984    Ménage fait trop vite et donc mal, puisque pou...
# 1985    Une formule agréable pour des vacances actives...
# 1986    Nous étions partis entre amis avec deux enfant...
# 1987    Personnel très agréable. Centre adapté aux jeu...
# 1988    Nous avons passé un très bon séjour. Le domain...
# 1989    Cottage mal entretenu. Activités très onéreuse...
# 1990    Très bon séjours... De très bonnes activités, ...
# 1991    Très joli parc au milieu d'une forêt. Beaucoup...
# 1992    Je me permet de noter seulement les restaurant...
# 1993    Nous venons de passer 10 jours au domaine, 1 w...
# Name: review, Length: 1994, dtype: object

# %%
df1.title = df1.title.apply(lambda x:x.replace(r"\u00e8","è"))
df1.title = df1.title.apply(lambda x:x.replace(r'\u00e9', 'é'))
df1.title = df1.title.apply(lambda x:x.replace(r"\u00ea","ê"))
df1.title = df1.title.apply(lambda x:x.replace(r"\u00eb","ë"))
df1.title = df1.title.apply(lambda x:x.replace(r"\u00f9","ù"))
df1.title = df1.title.apply(lambda x:x.replace(r'\u00ee', 'î'))
df1.title = df1.title.apply(lambda x:x.replace(r'\u00ef', 'ï'))
df1.title = df1.title.apply(lambda x:x.replace(r"\u00fb","û"))
df1.title = df1.title.apply(lambda x:x.replace(r'\u00e0', 'à'))
df1.title = df1.title.apply(lambda x:x.replace(r'\u00e2', 'â'))
df1.title = df1.title.apply(lambda x:x.replace(r'\u00f4', 'ô'))
df1.title = df1.title.apply(lambda x:x.replace(r'\u2019', "'"))
df1.title = df1.title.apply(lambda x:x.replace(r'\'', "'"))

df1.title
# Out:
# 0                               Petite semaine en famille
# 1                      center parcs la promesse des daims
# 2                                             A améliorer
# 3                                                Reposant
# 4                                   tres belle decouverte
# 5                                             Déconnexion
# 6                                         séjour agréable
# 7                                                 Piscine
# 8                                      Bof bof le service
# 9                                           SUPER  SEJOUR
# 10                                        Vraiment cool !
# 11                 relaxation et cocooning au rendez-vous
# 12                                   Confort et bien-être
# 13                                conforme à nos attentes
# 14              Très agréable en famille sauf le week-end
# 15        Séjour en mid-week du 21 janvier au 25 janvier.
# 16                                     Bon séjour sauf...
# 17                               Un bon moment de détente
# 18            Une bulle de décompression en plein hiver !
# 19                              Super moment en famille!!
# 20                                               Relaxant
# 21          Très satisfaits de notre WE, belle découverte
# 22                             Séjour agréable en famille
# 23                                              Excellent
# 24                    Un bon moment de détente en famille
# 25                                         que du bonheur
# 26                           Un séjour à faire en janvier
# 27                                                détente
# 28                                              Déception
# 29      Superbe séjour, je recommande une évasion au S...
#                               ...
# 1964                                        Super sejours
# 1965                                            Reposant
# 1966                                    Bilan mitigé....
# 1967                    La bulle: le paradis des enfants
# 1968                                          Parc super
# 1969                                      Aqua mundo top
# 1970                           Vacances avec bébé au top!
# 1971                                          Restaurant
# 1972                Un séjour en famille en pleine nature
# 1973                                     Excellent séjour
# 1974                                     Manque de nature
# 1975                                               génial
# 1976                                          Avis mitigé
# 1977                                              bof!!!!
# 1978                                 SEJOUR AVEC DES AMIS
# 1979                                        Enfant blessé
# 1980             Magnifique parc mais quelques faiblesses
# 1981                                             We sympa
# 1982                                                Sympa
# 1983                                           Dé\u00e7ue
# 1984                                             propreté
# 1985                                     Séjour Août 2017
# 1986       Un très bon séjour mais quelques quoiques !!!!
# 1987                                    on y retournera!!
# 1988           Très bon séjour bon déconnecter en famille
# 1989             de tous les center parcs, c'est le pire.
# 1990                               séjours Bois aux Daims
# 1991                                            Mitigé...
# 1992                        Ne pas aller aux restaurants
# 1993                       séjour bien , mais pas parfait
# Name: title, Length: 1994, dtype: object

# %%
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r"\u00e8","è"))
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r'\u00e9', 'é'))
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r"\u00ea","ê"))
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r"\u00eb","ë"))
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r"\u00f9","ù"))
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r'\u00ee', 'î'))
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r'\u00ef', 'ï'))
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r"\u00fb","û"))
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r'\u00e0', 'à'))
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r'\u00e2', 'â'))
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r'\u00f4', 'ô'))
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r'\u2019', "'"))
df1.trip_date = df1.trip_date.apply(lambda x:x.replace(r'\'', "'"))

# %%
df1
# Out:
#                           hotel_name   published_date  rating  \
# 0     Center Parcs Le Bois aux Daims   1 février 2019       5
# 1     Center Parcs Le Bois aux Daims   1 février 2019       5
# 2     Center Parcs Le Bois aux Daims   1 février 2019       3
# 3     Center Parcs Le Bois aux Daims   1 février 2019       3
# 4     Center Parcs Le Bois aux Daims   2 février 2019       5
# 5     Center Parcs Le Bois aux Daims  30 janvier 2019       4
# 6     Center Parcs Le Bois aux Daims  30 janvier 2019       5
# 7     Center Parcs Le Bois aux Daims  30 janvier 2019       2
# 8     Center Parcs Le Bois aux Daims  31 janvier 2019       1
# 9     Center Parcs Le Bois aux Daims  31 janvier 2019       5
# 10    Center Parcs Le Bois aux Daims  29 janvier 2019       5
# 11    Center Parcs Le Bois aux Daims  29 janvier 2019       5
# 12    Center Parcs Le Bois aux Daims  29 janvier 2019       4
# 13    Center Parcs Le Bois aux Daims  30 janvier 2019       4
# 14    Center Parcs Le Bois aux Daims  30 janvier 2019       4
# 5     Center parc est un endroit très relaxant et en...              fr
# 6     agréablement surpris super séjour bien reposer...              fr
# 7     Piscine bondée de monde !! Et pourtant hors pé...              fr
# 8     Le personnel du service client n'a pas été à l...              fr
# 9     Un vrai paradis pour déconnecter du travail, d...              fr
# 10    10 jours de détente en famille, que ce soit au...              fr
# 11    très beau cadre en harmonie avec la naturedéco...              fr
# 12    Séjour très agréable, très bon accueil, cottag...              fr
# 13    le parc est calme , la nature est partout  et ...              fr
# 14    Très bonnes installations. Seul bémol quota de...              fr
# 15    Nous sommes venus en famille avec une amie et ...              fr
# 16    Nous avons passé un très bon séjour! L 'enviro...              fr
# 17    Le cottage VIP 6 personnes était juste super!!...              fr
# 18    Toujours aussi bien j'y vais toujours avec pla...              fr
# 19    Premier séjour à Center Parcs en famille avec ...              fr
# 20    Cottage très bien agencé pour une famille nomb...              fr
# 21    Bel endroit, très calme au niveau des cottages...              fr
# 22    Bon séjour passé en famille le côté nature éta...              fr
# 23    Nous avons passé une super semaine en famille....              fr
# 24    Très dépaysant , surtout en hiver.Très adapté ...              fr
# 25    émerveillement pour les enfants: l'endroit ide...              fr
# 26    Un séjour magique en famille. Nous y sommes al...              fr
# 27    c'est bon de pouvoir se baigner dans une eau&q...              fr
# 28    Un geste commercial serait apprécié compte ten...              fr
# 29    Je recommande center parc à toutes les personn...              fr
# ...                                                 ...             ...
# 1964  Cottage très agréable,  parcs très calme et sé...              fr
# 1965  Le concept est reposant, les daims vous renden...              fr
# 1966  Bonnes infrastructures neuves et de qualité ma...              fr
# 1967  Notre troisième séjour à Center parcs est iden...              fr
# 1968  C est la troisième fois que nous venons passer...              fr
# 1969  Passer une journée dans le Center Parcs avis m...              fr
# 1970  Nous sommes partis une semaine en cottage prem...              fr
# 1971  Domaine magnifique dommage que le services dan...              fr
# 1972  Ce séjour à Center Parcs était une grande prem...              fr
# 1973  4 jours passés, très agréable le cottage très ...              fr
# 1974  Nous avons voulu tester ce parc car moins loin...              fr
# 1975  Mes 2 miss de 10 ans ont été éblouies et se so...              fr
# 1976  Le parc, la piscine et le cottage sont très ag...              fr
# 1977  emplacement ok,ménage: moutons de poussière so...              fr
# 1978  Nous avons passés un agréable séjour à Center ...              fr
# 1979  Mon enfant est tombé sur le nez en montant les...              fr
# 1980  Le parc est magnifique, les daims sont bien pr...              fr
# 1981  We très sympa a Center Parcs ressour\u00e7ant ...              fr
# 1982  VACANCES sympa la cadre et les daims beaux spe...              fr
# 1983  Tres dé\u00e7u par le bois aux daimsC'est le 2...              fr
# 1984  Ménage fait trop vite et donc mal, puisque pou...              fr
# 1985  Une formule agréable pour des vacances actives...              fr
# 1986  Nous étions partis entre amis avec deux enfant...              fr
# 1987  Personnel très agréable. Centre adapté aux jeu...              fr
# 1988  Nous avons passé un très bon séjour. Le domain...              fr
# 1989  Cottage mal entretenu. Activités très onéreuse...              fr
# 1990  Très bon séjours... De très bonnes activités, ...              fr
# 1991  Très joli parc au milieu d'une forêt. Beaucoup...              fr
# 1992  Je me permet de noter seulement les restaurant...              fr
# 1993  Nous venons de passer 10 jours au domaine, 1 w...              fr
#
#                                                   title       trip_date
# 0                             Petite semaine en famille    janvier 2019
# 1                    center parcs la promesse des daims    janvier 2019
# 2                                           A améliorer    janvier 2019
# 3                                              Reposant    février 2019
# 4                                 tres belle decouverte    janvier 2019
# 5                                           Déconnexion    janvier 2019
# 6                                       séjour agréable    janvier 2019
# 7                                               Piscine    janvier 2019
# 8                                    Bof bof le service   novembre 2018
# 9                                         SUPER  SEJOUR    janvier 2019
# 10                                      Vraiment cool !    janvier 2019
# 11               relaxation et cocooning au rendez-vous    janvier 2019
# 12                                 Confort et bien-être    janvier 2019
# 13                              conforme à nos attentes    janvier 2019
# 14            Très agréable en famille sauf le week-end    janvier 2019
# 15      Séjour en mid-week du 21 janvier au 25 janvier.    janvier 2019
# 16                                   Bon séjour sauf...    janvier 2019
# 17                             Un bon moment de détente    janvier 2019
# 18          Une bulle de décompression en plein hiver !    janvier 2019
# 19                            Super moment en famille!!    janvier 2019
# 20                                             Relaxant    janvier 2019
# 21        Très satisfaits de notre WE, belle découverte    janvier 2019
# 22                           Séjour agréable en famille    janvier 2019
# 23                                            Excellent    janvier 2019
# 24                  Un bon moment de détente en famille    janvier 2019
# 25                                       que du bonheur    janvier 2019
# 26                         Un séjour à faire en janvier    janvier 2019
# 27                                              détente    janvier 2019
# 28                                            Déception    janvier 2019
# 29    Superbe séjour, je recommande une évasion au S...    janvier 2019
# ...                                                 ...             ...
# 1964                                      Super sejours       août 2017
# 1965                                          Reposant        août 2017
# 1966                                  Bilan mitigé....        août 2017
# 1967                  La bulle: le paradis des enfants        août 2017
# 1968                                        Parc super        août 2017
# 1969                                    Aqua mundo top        août 2017
# 1970                         Vacances avec bébé au top!       août 2017
# 1971                                        Restaurant        août 2017
# 1972              Un séjour en famille en pleine nature       août 2017
# 1973                                   Excellent séjour    juillet 2017
# 1974                                   Manque de nature       août 2017
# 1975                                             génial       août 2017
# 1976                                        Avis mitigé       août 2017
# 1977                                            bof!!!!       août 2017
# 1978                               SEJOUR AVEC DES AMIS       août 2017
# 1979                                      Enfant blessé       août 2017
# 1980           Magnifique parc mais quelques faiblesses       août 2017
# 1981                                           We sympa       août 2017
# 1982                                              Sympa       août 2017
# 1983                                         Dé\u00e7ue       août 2017
# 1984                                           propreté       août 2017
# 1985                                   Séjour Août 2017       août 2017
# 1986     Un très bon séjour mais quelques quoiques !!!!       août 2017
# 1987                                  on y retournera!!       août 2017
# 1988         Très bon séjour bon déconnecter en famille       août 2017
# 1989           de tous les center parcs, c'est le pire.       août 2017
# 1990                             séjours Bois aux Daims       août 2017
# 1991                                          Mitigé...       août 2017
# 1992                      Ne pas aller aux restaurants        août 2017
# 1993                     séjour bien , mais pas parfait       août 2017
#
# [1994 rows x 7 columns]

# %%
df1.to_csv('clean_data_gr4_en.csv', sep = ";", encoding = "utf-8")

# %%
essai = pd.read_csv('clean_data_gr4_en.csv', sep = ";", encoding = "utf-8",index_col = None)
essai
# Out:
#      Unnamed: 0                      hotel_name      published_date  rating  \
# 0             0  Center Parcs Le Bois aux Daims  September 26, 2018       3
# 1             1  Center Parcs Le Bois aux Daims     October 1, 2018       3
# 198         198  Center Parcs Le Bois aux Daims     August 18, 2015       3
# 199         199  Center Parcs Le Bois aux Daims     August 23, 2015       4
# 200         200  Center Parcs Le Bois aux Daims       July 29, 2015       4
# 201         201  Center Parcs Le Bois aux Daims       July 30, 2015       5
# 202         202  Center Parcs Le Bois aux Daims       July 30, 2015       5
# 203         203  Center Parcs Le Bois aux Daims       July 31, 2015       5
# 204         204  Center Parcs Le Bois aux Daims      August 3, 2015       4
# 205         205  Center Parcs Le Bois aux Daims       June 30, 2015       2
# 206         206  Center Parcs Le Bois aux Daims       July 17, 2015       4
# 207         207  Center Parcs Le Bois aux Daims       July 25, 2015       4
#
#                                                 review review_language  \
# 0    Plenty to do for amusement. Paying activities ...              en
# 1    Nice place to relax, The park is quiet and gre...              en
# 2    we had a lovely long weekend and it was tough ...              en
# 3    Thoroughly enjoyable time at Bois aux daims, e...              en
# 4    Can\u2019t complain except for the fact that t...              en
# 5    We stayed 4 nights in a treehouse - which was ...              en
# 6    We paid for a premium cottage yet we turned up...              en
# 7    Our stay at Les Bois Aux Daims was amazing. Gr...              en
# 8    Very nice and natural environment, secure acti...              en
# 9    Have been to Center Parcs over a decade ago we...              en
# 10   This was our first attempt at center Parcs out...              en
# 11   We have had two holidays here with our twins (...              en
# 12   We had a lovely weekend here in August. 2 adul...              en
# 13   We spent a week here with our kids in august 2...              en
# 14   So a lot of the services, for example, the int...              en
# 15   I have mixed feelings about Le Bois aux Daims....              en
# 16   overall It was a very good holiday. only the l...              en
# 17   After more holidays on French campsites than a...              en
# 18   Fantastic facilities for children, ours loved ...              en
# 19   We have visited many on the sites in the UK an...              en
# 20   First the positives:1. The forest setting is m...              en
# 21   A few amendments could make this truly a great...              en
# 22   This was our second year in Le Bois aux Daims ...              en
# 23   Great for kids, did the climbing activity whic...              en
# 24   Unfortunately when we unpacked our \u201cclean...              en
# 25   On arrival our VIP 8 person cottage looked ama...              en
# 26   A fun holiday with our two pre schoolers. The ...              en
# 27   Center Parcs Le Bois aux Daims was an all roun...              en
# 28   We stayed in the new Treehouses and it was AMA...              en
# 29   We booked and paid for 2 weeks in the VIP lodg...              en
# ..                                                 ...             ...
# 178  Today, April 1st, NOT a SINGLE activity availa...              en
# 179  We are seasoned Center Parcs family and have v...              en
# 180  We took advantage of some inset days to book a...              en
# 181  Was unsure when I first booked as this was the...              en
# 182  Excellent stay, very good services, the domain...              en
# 183  Stayed one week in August 2015 with partner an...              en
# 184  We had a VIP bungalow for two weeks, very beau...              en
# 185  The cottage was wonderful, very quiet, nice bi...              en
# 186  We booked our holiday at Le Bois Aux Daims bef...              en
# 187  We stayed for the mid week at the start of Sep...              en
# 188  Any brand-spanking new venue is bound to be go...              en
# 189  We stayed for the first week of September with...              en
# 190  We booked a last minute week\'s holiday. As th...              en
# 191  This was our first visit to CP France although...              en
# 192  First time at a continental CPs and weren\'t d...              en
# 193  We had a great time at this Centre Parcs with ...              en
# 194  We\'re a family of 5 with kids age 7, 5 and 3....              en
# 195  We\'ve been to  five Centreparcs across the UK...              en
# 196  This is a new resort opened circa may 15 so ex...              en
# 197  This will become an amazing centre Parcs howev...              en
